# %%
import os
os.chdir("..")

# %run main.py
# Out:
# === SOIL QUALITY CHECKER ===
# Model Accuracy: 99.09%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.94      0.94      0.94        36
#     Moderate       0.99      0.99      0.99       150
#         Poor       1.00      1.00      1.00       254
#
#     accuracy                           0.99       440
#    macro avg       0.98      0.98      0.98       440
# weighted avg       0.99      0.99      0.99       440
# Chart saved to outputs/soil_quality_chart.png
#
# Sample Prediction (N=90, P=42, K=43, pH=6.5, Humidity=70%): Good
#
# === IRRIGATION NEED ANALYSIS ===
# Model Accuracy: 100.00%
# Chart saved to outputs/irrigation_chart.png
#
# Sample Prediction (Rainfall=50mm, Humidity=55%): Irrigation Need = High
#
# === CROP PRODUCTION ANALYSIS ===
# Model Accuracy: 99.32%
# Chart saved to outputs/crop_production_chart.png
#
# Recommended Crop for given conditions: rice
#
# === WEATHER PREDICTOR ===
# ...
